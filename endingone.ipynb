# %%
! wget http://www.ehu.eus/ccwintco/uploads/6/67/Indian_pines_corrected.mat
! wget http://www.ehu.eus/ccwintco/uploads/c/c4/Indian_pines_gt.mat
! pip install spectral
# Out:
# --2022-11-23 11:01:36--  http://www.ehu.eus/ccwintco/uploads/6/67/Indian_pines_corrected.mat
# Resolving www.ehu.eus (www.ehu.eus)... 158.227.0.65, 2001:720:1410::65
# Connecting to www.ehu.eus (www.ehu.eus)|158.227.0.65|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.ehu.eus/ccwintco/uploads/6/67/Indian_pines_corrected.mat [following]
# --2022-11-23 11:01:36--  https://www.ehu.eus/ccwintco/uploads/6/67/Indian_pines_corrected.mat
# Connecting to www.ehu.eus (www.ehu.eus)|158.227.0.65|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5953527 (5.7M)
# Saving to: ‘Indian_pines_corrected.mat’
#
# Indian_pines_correc 100%[===================>]   5.68M  2.15MB/s    in 2.6s
#
# 2022-11-23 11:01:39 (2.15 MB/s) - ‘Indian_pines_corrected.mat’ saved [5953527/5953527]
#
# URL transformed to HTTPS due to an HSTS policy
# --2022-11-23 11:01:39--  https://www.ehu.eus/ccwintco/uploads/c/c4/Indian_pines_gt.mat
# Resolving www.ehu.eus (www.ehu.eus)... 158.227.0.65, 2001:720:1410::65
# Connecting to www.ehu.eus (www.ehu.eus)|158.227.0.65|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1125 (1.1K)
# Saving to: ‘Indian_pines_gt.mat’
#
# Indian_pines_gt.mat 100%[===================>]   1.10K  --.-KB/s    in 0s
#
# 2022-11-23 11:01:39 (78.9 MB/s) - ‘Indian_pines_gt.mat’ saved [1125/1125]
#
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting spectral
#   Downloading spectral-0.23.1-py3-none-any.whl (212 kB)
#      |████████████████████████████████| 212 kB 32.9 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from spectral) (1.21.6)
# Installing collected packages: spectral
# Successfully installed spectral-0.23.1

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, cohen_kappa_score
import spectral
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
class_num = 16#地物类别为16

class HybridSN(nn.Module):
  def __init__(self):
    super(HybridSN, self).__init__()
    
    #卷积层
    #先做三次三维的卷积，再做一次二维的卷积
    self.conv1 = nn.Conv3d(1, 8, kernel_size=(7,3,3), stride=1, padding=0)
    self.conv2 = nn.Conv3d(8, 16, kernel_size=(5,3,3), stride=1, padding=0)
    self.conv3 = nn.Conv3d(16, 32, kernel_size=(3,3,3), stride=1, padding=0)
    
    
    self.conv4 = nn.Conv2d(576, 64, kernel_size=(3,3), stride=1, padding=0)

	  #attention parameter
    self.conv_phi = nn.Conv2d(576, 576, kernel_size=(1,1), stride=1, padding=0)
    self.conv_theta = nn.Conv2d(576, 576, kernel_size=(1,1), stride=1, padding=0)
    self.conv_g = nn.Conv2d(576, 576, kernel_size=(1,1), stride=1, padding=0)
    self.softmax = nn.Softmax(dim=1)
    self.conv_mask = nn.Conv2d(576, 576, kernel_size=(1,1), stride=1, padding=0)
    
    #全连接层
    self.fc1 = nn.Linear(18496, 256)
    self.fc2 = nn.Linear(256, 128)
    self.fc3 = nn.Linear(128, 16)
    
    self.dropout = nn.Dropout(0.4)

  def attention(self, x):
    # [N, C, H , W]
    b, c, h, w = x.size()
    # [N, C/2, H * W]
    x_phi = self.conv_phi(x).view(b, c, -1)
    # [N, H * W, C/2]
    x_theta = self.conv_theta(x).view(b, c, -1).permute(0, 2, 1).contiguous()
    x_g = self.conv_g(x).view(b, c, -1).permute(0, 2, 1).contiguous()
    #print(x_phi.size(), x_theta.size(), x_g.size())
    # [N, H * W, H * W]
    mul_theta_phi = torch.matmul(x_theta, x_phi)
    mul_theta_phi = self.softmax(mul_theta_phi)
    # [N, H * W, C/2]
    mul_theta_phi_g = torch.matmul(mul_theta_phi, x_g)
    # [N, C/2, H, W]
    mul_theta_phi_g = mul_theta_phi_g.permute(0,2,1).contiguous().view(b, c, h, w)
    # [N, C, H , W]
    mask = self.conv_mask(mul_theta_phi_g)
    out = mask + x
    return out

  def forward(self, x):
    x = self.conv1(x)
    x = F.relu(x)#relu函数激活
    
    x = self.conv2(x)
    x = F.relu(x)
    
    x = self.conv3(x)
    x = F.relu(x)
    
    x = x.reshape(x.shape[0],-1,19,19)
    

    x = self.attention(x)
    x = self.conv4(x)
    x = F.relu(x)
    x = x.flatten(start_dim = 1)
    x = self.fc1(x)
    x = self.dropout(x)
    x = F.relu(x)
    x = self.fc2(x)
    x = self.dropout(x)
    x = F.relu(x)
    x = self.fc3(x)
    return x

# %%
 #对高光谱数据 X 应用 PCA 变换
def applyPCA(X, numComponents):
    newX = np.reshape(X, (-1, X.shape[2]))
    pca = PCA(n_components=numComponents, whiten=True)
    newX = pca.fit_transform(newX)
    newX = np.reshape(newX, (X.shape[0], X.shape[1], numComponents))
    return newX

# 对单个像素周围提取 patch 时，边缘像素就无法取了，因此，给这部分像素进行 padding 操作
def padWithZeros(X, margin=2):
    newX = np.zeros((X.shape[0] + 2 * margin, X.shape[1] + 2* margin, X.shape[2]))
    x_offset = margin
    y_offset = margin
    newX[x_offset:X.shape[0] + x_offset, y_offset:X.shape[1] + y_offset, :] = X
    return newX

# 在每个像素周围提取 patch ，然后创建成符合 keras 处理的格式
def createImageCubes(X, y, windowSize=5, removeZeroLabels = True):
    # 给 X 做 padding
    margin = int((windowSize - 1) / 2)
    zeroPaddedX = padWithZeros(X, margin=margin)
    # split patches
    patchesData = np.zeros((X.shape[0] * X.shape[1], windowSize, windowSize, X.shape[2]))
    patchesLabels = np.zeros((X.shape[0] * X.shape[1]))
    patchIndex = 0
    for r in range(margin, zeroPaddedX.shape[0] - margin):
        for c in range(margin, zeroPaddedX.shape[1] - margin):
            patch = zeroPaddedX[r - margin:r + margin + 1, c - margin:c + margin + 1]   
            patchesData[patchIndex, :, :, :] = patch
            patchesLabels[patchIndex] = y[r-margin, c-margin]
            patchIndex = patchIndex + 1
    if removeZeroLabels:
        patchesData = patchesData[patchesLabels>0,:,:,:]
        patchesLabels = patchesLabels[patchesLabels>0]
        patchesLabels -= 1
    return patchesData, patchesLabels

def splitTrainTestSet(X, y, testRatio, randomState=345):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=testRatio, random_state=randomState, stratify=y)
    return X_train, X_test, y_train, y_test

# %%
# 地物类别
class_num = 16
X = sio.loadmat('Indian_pines_corrected.mat')['indian_pines_corrected']
y = sio.loadmat('Indian_pines_gt.mat')['indian_pines_gt']

# 用于测试样本的比例
test_ratio = 0.90
# 每个像素周围提取 patch 的尺寸
patch_size = 25
# 使用 PCA 降维，得到主成分的数量
pca_components = 30

print('Hyperspectral data shape: ', X.shape)
print('Label shape: ', y.shape)

print('\n... ... PCA tranformation ... ...')
X_pca = applyPCA(X, numComponents=pca_components)
print('Data shape after PCA: ', X_pca.shape)

print('\n... ... create data cubes ... ...')
X_pca, y = createImageCubes(X_pca, y, windowSize=patch_size)
print('Data cube X shape: ', X_pca.shape)
print('Data cube y shape: ', y.shape)

print('\n... ... create train & test data ... ...')
Xtrain, Xtest, ytrain, ytest = splitTrainTestSet(X_pca, y, test_ratio)
print('Xtrain shape: ', Xtrain.shape)
print('Xtest  shape: ', Xtest.shape)

# 改变 Xtrain, Ytrain 的形状，以符合 keras 的要求
Xtrain = Xtrain.reshape(-1, patch_size, patch_size, pca_components, 1)
Xtest  = Xtest.reshape(-1, patch_size, patch_size, pca_components, 1)
print('before transpose: Xtrain shape: ', Xtrain.shape) 
print('before transpose: Xtest  shape: ', Xtest.shape) 

# 为了适应 pytorch 结构，数据要做 transpose
Xtrain = Xtrain.transpose(0, 4, 3, 1, 2)
Xtest  = Xtest.transpose(0, 4, 3, 1, 2)
print('after transpose: Xtrain shape: ', Xtrain.shape) 
print('after transpose: Xtest  shape: ', Xtest.shape) 


""" Training dataset"""
class TrainDS(torch.utils.data.Dataset): 
    def __init__(self):
        self.len = Xtrain.shape[0]
        self.x_data = torch.FloatTensor(Xtrain)
        self.y_data = torch.LongTensor(ytrain)        
    def __getitem__(self, index):
        # 根据索引返回数据和对应的标签
        return self.x_data[index], self.y_data[index]
    def __len__(self): 
        # 返回文件数据的数目
        return self.len

""" Testing dataset"""
class TestDS(torch.utils.data.Dataset): 
    def __init__(self):
        self.len = Xtest.shape[0]
        self.x_data = torch.FloatTensor(Xtest)
        self.y_data = torch.LongTensor(ytest)
    def __getitem__(self, index):
        # 根据索引返回数据和对应的标签
        return self.x_data[index], self.y_data[index]
    def __len__(self): 
        # 返回文件数据的数目
        return self.len

# 创建 trainloader 和 testloader
trainset = TrainDS()
testset  = TestDS()
train_loader = torch.utils.data.DataLoader(dataset=trainset, batch_size=128, shuffle=True, num_workers=2)
test_loader  = torch.utils.data.DataLoader(dataset=testset,  batch_size=128, shuffle=False, num_workers=2)
# Out:
# Hyperspectral data shape:  (145, 145, 200)
# Label shape:  (145, 145)
#
# ... ... PCA tranformation ... ...
# Data shape after PCA:  (145, 145, 30)
#
# ... ... create data cubes ... ...
# Data cube X shape:  (10249, 25, 25, 30)
# Data cube y shape:  (10249,)
#
# ... ... create train & test data ... ...
# Xtrain shape:  (1024, 25, 25, 30)
# Xtest  shape:  (9225, 25, 25, 30)
# before transpose: Xtrain shape:  (1024, 25, 25, 30, 1)
# before transpose: Xtest  shape:  (9225, 25, 25, 30, 1)
# after transpose: Xtrain shape:  (1024, 1, 30, 25, 25)
# after transpose: Xtest  shape:  (9225, 1, 30, 25, 25)

# %%
# 使用GPU训练
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 网络放到GPU上
net = HybridSN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)

# 开始训练
total_loss = 0
for epoch in range(300):
    for i, (inputs, labels) in enumerate(train_loader):
        inputs = inputs.to(device)
        labels = labels.to(device)
        # 优化器梯度归零
        optimizer.zero_grad()
        # 正向传播 +　反向传播 + 优化 
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    print('[Epoch: %d]   [loss avg: %.4f]   [current loss: %.4f]' %(epoch + 1, total_loss/(epoch+1), loss.item()))

print('Finished Training')
# Out:
# [Epoch: 1]   [loss avg: 24.7063]   [current loss: 2.7058]
# [Epoch: 2]   [loss avg: 22.6769]   [current loss: 2.5428]
# [Epoch: 3]   [loss avg: 21.6964]   [current loss: 2.4653]
# [Epoch: 4]   [loss avg: 21.1184]   [current loss: 2.4384]
# [Epoch: 5]   [loss avg: 20.7398]   [current loss: 2.3688]
# [Epoch: 6]   [loss avg: 20.4256]   [current loss: 2.3424]
# [Epoch: 7]   [loss avg: 20.1569]   [current loss: 2.3261]
# [Epoch: 8]   [loss avg: 19.8328]   [current loss: 2.2024]
# [Epoch: 9]   [loss avg: 19.4430]   [current loss: 2.1851]
# [Epoch: 10]   [loss avg: 19.0187]   [current loss: 1.7702]
# [Epoch: 11]   [loss avg: 18.5927]   [current loss: 1.7054]
# [Epoch: 12]   [loss avg: 18.1700]   [current loss: 1.7598]
# [Epoch: 13]   [loss avg: 17.7428]   [current loss: 1.6215]
# [Epoch: 14]   [loss avg: 17.3247]   [current loss: 1.3995]
# [Epoch: 15]   [loss avg: 16.8876]   [current loss: 1.4035]
# [Epoch: 16]   [loss avg: 16.4790]   [current loss: 1.2987]
# [Epoch: 17]   [loss avg: 16.0905]   [current loss: 1.2801]
# [Epoch: 18]   [loss avg: 15.6970]   [current loss: 1.1821]
# [Epoch: 19]   [loss avg: 15.2886]   [current loss: 0.9844]
# [Epoch: 20]   [loss avg: 14.8540]   [current loss: 0.9092]
# [Epoch: 21]   [loss avg: 14.4255]   [current loss: 0.8533]
# [Epoch: 22]   [loss avg: 14.0197]   [current loss: 0.6897]
# [Epoch: 23]   [loss avg: 13.6180]   [current loss: 0.5839]
# [Epoch: 24]   [loss avg: 13.2013]   [current loss: 0.3556]
# [Epoch: 25]   [loss avg: 12.7763]   [current loss: 0.2770]
# [Epoch: 26]   [loss avg: 12.3704]   [current loss: 0.3320]
# [Epoch: 27]   [loss avg: 11.9767]   [current loss: 0.1401]
# [Epoch: 28]   [loss avg: 11.6625]   [current loss: 0.4731]
# [Epoch: 29]   [loss avg: 11.3530]   [current loss: 0.1772]
# [Epoch: 30]   [loss avg: 11.0291]   [current loss: 0.3070]
# [Epoch: 31]   [loss avg: 10.7180]   [current loss: 0.1247]
# [Epoch: 32]   [loss avg: 10.4178]   [current loss: 0.1707]
# [Epoch: 33]   [loss avg: 10.1268]   [current loss: 0.0553]
# [Epoch: 34]   [loss avg: 9.8453]   [current loss: 0.1008]
# [Epoch: 35]   [loss avg: 9.5822]   [current loss: 0.0574]
# [Epoch: 36]   [loss avg: 9.3304]   [current loss: 0.0738]
# [Epoch: 37]   [loss avg: 9.0915]   [current loss: 0.0282]
# [Epoch: 38]   [loss avg: 8.8681]   [current loss: 0.1033]
# [Epoch: 39]   [loss avg: 8.6533]   [current loss: 0.0772]
# [Epoch: 40]   [loss avg: 8.4451]   [current loss: 0.0261]
# [Epoch: 41]   [loss avg: 8.2482]   [current loss: 0.0140]
# [Epoch: 42]   [loss avg: 8.0572]   [current loss: 0.0409]
# [Epoch: 43]   [loss avg: 7.8786]   [current loss: 0.0438]
# [Epoch: 44]   [loss avg: 7.7034]   [current loss: 0.0212]
# [Epoch: 45]   [loss avg: 7.5383]   [current loss: 0.0410]
# [Epoch: 46]   [loss avg: 7.3794]   [current loss: 0.1107]
# [Epoch: 47]   [loss avg: 7.2370]   [current loss: 0.1832]
# [Epoch: 48]   [loss avg: 7.1000]   [current loss: 0.0283]
# [Epoch: 49]   [loss avg: 6.9753]   [current loss: 0.0383]
# [Epoch: 50]   [loss avg: 6.8485]   [current loss: 0.0249]
# [Epoch: 51]   [loss avg: 6.7253]   [current loss: 0.1180]
# [Epoch: 52]   [loss avg: 6.6061]   [current loss: 0.1899]
# [Epoch: 53]   [loss avg: 6.4896]   [current loss: 0.0240]
# [Epoch: 54]   [loss avg: 6.3764]   [current loss: 0.0268]
# [Epoch: 55]   [loss avg: 6.2655]   [current loss: 0.0215]
# [Epoch: 56]   [loss avg: 6.1560]   [current loss: 0.0507]
# [Epoch: 57]   [loss avg: 6.0524]   [current loss: 0.0397]
# [Epoch: 58]   [loss avg: 5.9517]   [current loss: 0.0428]
# [Epoch: 59]   [loss avg: 5.8519]   [current loss: 0.0091]
# [Epoch: 60]   [loss avg: 5.7569]   [current loss: 0.0045]
# [Epoch: 61]   [loss avg: 5.6632]   [current loss: 0.0027]
# [Epoch: 62]   [loss avg: 5.5778]   [current loss: 0.0051]
# [Epoch: 63]   [loss avg: 5.4916]   [current loss: 0.0044]
# [Epoch: 64]   [loss avg: 5.4066]   [current loss: 0.0136]
# [Epoch: 65]   [loss avg: 5.3289]   [current loss: 0.0382]
# [Epoch: 66]   [loss avg: 5.2504]   [current loss: 0.0113]
# [Epoch: 67]   [loss avg: 5.1748]   [current loss: 0.0125]
# [Epoch: 68]   [loss avg: 5.1002]   [current loss: 0.0025]
# [Epoch: 69]   [loss avg: 5.0277]   [current loss: 0.0029]
# [Epoch: 70]   [loss avg: 4.9573]   [current loss: 0.0262]
# [Epoch: 71]   [loss avg: 4.8889]   [current loss: 0.0044]
# [Epoch: 72]   [loss avg: 4.8231]   [current loss: 0.0328]
# [Epoch: 73]   [loss avg: 4.7587]   [current loss: 0.0270]
# [Epoch: 74]   [loss avg: 4.6954]   [current loss: 0.0009]
# [Epoch: 75]   [loss avg: 4.6334]   [current loss: 0.0049]
# [Epoch: 76]   [loss avg: 4.5738]   [current loss: 0.0093]
# [Epoch: 77]   [loss avg: 4.5154]   [current loss: 0.0344]
# [Epoch: 78]   [loss avg: 4.4579]   [current loss: 0.0127]
# [Epoch: 79]   [loss avg: 4.4017]   [current loss: 0.0003]
# [Epoch: 80]   [loss avg: 4.3469]   [current loss: 0.0053]
# [Epoch: 81]   [loss avg: 4.2935]   [current loss: 0.0002]
# [Epoch: 82]   [loss avg: 4.2470]   [current loss: 0.1049]
# [Epoch: 83]   [loss avg: 4.2090]   [current loss: 0.0521]
# [Epoch: 84]   [loss avg: 4.1658]   [current loss: 0.0617]
# [Epoch: 85]   [loss avg: 4.1201]   [current loss: 0.0848]
# [Epoch: 86]   [loss avg: 4.0798]   [current loss: 0.1425]
# [Epoch: 87]   [loss avg: 4.0418]   [current loss: 0.0306]
# [Epoch: 88]   [loss avg: 3.9995]   [current loss: 0.0176]
# [Epoch: 89]   [loss avg: 3.9594]   [current loss: 0.0145]
# [Epoch: 90]   [loss avg: 3.9198]   [current loss: 0.0394]
# [Epoch: 91]   [loss avg: 3.8791]   [current loss: 0.0036]
# [Epoch: 92]   [loss avg: 3.8378]   [current loss: 0.0114]
# [Epoch: 93]   [loss avg: 3.7972]   [current loss: 0.0058]
# [Epoch: 94]   [loss avg: 3.7594]   [current loss: 0.0993]
# [Epoch: 95]   [loss avg: 3.7252]   [current loss: 0.0408]
# [Epoch: 96]   [loss avg: 3.6910]   [current loss: 0.0835]
# [Epoch: 97]   [loss avg: 3.6571]   [current loss: 0.0086]
# [Epoch: 98]   [loss avg: 3.6217]   [current loss: 0.0167]
# [Epoch: 99]   [loss avg: 3.5868]   [current loss: 0.0050]
# [Epoch: 100]   [loss avg: 3.5525]   [current loss: 0.0430]
# [Epoch: 101]   [loss avg: 3.5185]   [current loss: 0.0081]
# [Epoch: 102]   [loss avg: 3.4881]   [current loss: 0.0249]
# [Epoch: 103]   [loss avg: 3.4582]   [current loss: 0.0124]
# [Epoch: 104]   [loss avg: 3.4257]   [current loss: 0.0142]
# [Epoch: 105]   [loss avg: 3.3944]   [current loss: 0.0216]
# [Epoch: 106]   [loss avg: 3.3643]   [current loss: 0.0721]
# [Epoch: 107]   [loss avg: 3.3367]   [current loss: 0.0692]
# [Epoch: 108]   [loss avg: 3.3087]   [current loss: 0.0037]
# [Epoch: 109]   [loss avg: 3.2800]   [current loss: 0.0898]
# [Epoch: 110]   [loss avg: 3.2518]   [current loss: 0.0556]
# [Epoch: 111]   [loss avg: 3.2237]   [current loss: 0.0023]
# [Epoch: 112]   [loss avg: 3.1952]   [current loss: 0.0019]
# [Epoch: 113]   [loss avg: 3.1675]   [current loss: 0.0021]
# [Epoch: 114]   [loss avg: 3.1408]   [current loss: 0.0034]
# [Epoch: 115]   [loss avg: 3.1145]   [current loss: 0.0145]
# [Epoch: 116]   [loss avg: 3.0879]   [current loss: 0.0008]
# [Epoch: 117]   [loss avg: 3.0618]   [current loss: 0.0058]
# [Epoch: 118]   [loss avg: 3.0361]   [current loss: 0.0026]
# [Epoch: 119]   [loss avg: 3.0114]   [current loss: 0.0106]
# [Epoch: 120]   [loss avg: 2.9893]   [current loss: 0.0110]
# [Epoch: 121]   [loss avg: 2.9664]   [current loss: 0.0857]
# [Epoch: 122]   [loss avg: 2.9446]   [current loss: 0.0102]
# [Epoch: 123]   [loss avg: 2.9239]   [current loss: 0.0702]
# [Epoch: 124]   [loss avg: 2.9038]   [current loss: 0.0673]
# [Epoch: 125]   [loss avg: 2.8854]   [current loss: 0.1001]
# [Epoch: 126]   [loss avg: 2.8650]   [current loss: 0.0093]
# [Epoch: 127]   [loss avg: 2.8465]   [current loss: 0.0064]
# [Epoch: 128]   [loss avg: 2.8269]   [current loss: 0.0384]
# [Epoch: 129]   [loss avg: 2.8102]   [current loss: 0.0609]
# [Epoch: 130]   [loss avg: 2.7910]   [current loss: 0.0319]
# [Epoch: 131]   [loss avg: 2.7787]   [current loss: 0.2226]
# [Epoch: 132]   [loss avg: 2.7747]   [current loss: 0.0800]
# [Epoch: 133]   [loss avg: 2.7648]   [current loss: 0.2049]
# [Epoch: 134]   [loss avg: 2.7488]   [current loss: 0.1436]
# [Epoch: 135]   [loss avg: 2.7353]   [current loss: 0.2486]
# [Epoch: 136]   [loss avg: 2.7208]   [current loss: 0.0077]
# [Epoch: 137]   [loss avg: 2.7080]   [current loss: 0.0229]
# [Epoch: 138]   [loss avg: 2.6939]   [current loss: 0.0036]
# [Epoch: 139]   [loss avg: 2.6786]   [current loss: 0.0136]
# [Epoch: 140]   [loss avg: 2.6619]   [current loss: 0.0381]
# [Epoch: 141]   [loss avg: 2.6453]   [current loss: 0.0338]
# [Epoch: 142]   [loss avg: 2.6299]   [current loss: 0.0528]
# [Epoch: 143]   [loss avg: 2.6135]   [current loss: 0.0230]
# [Epoch: 144]   [loss avg: 2.5988]   [current loss: 0.1828]
# [Epoch: 145]   [loss avg: 2.5815]   [current loss: 0.0012]
# [Epoch: 146]   [loss avg: 2.5681]   [current loss: 0.0895]
# [Epoch: 147]   [loss avg: 2.5531]   [current loss: 0.0041]
# [Epoch: 148]   [loss avg: 2.5380]   [current loss: 0.0090]
# [Epoch: 149]   [loss avg: 2.5230]   [current loss: 0.0073]
# [Epoch: 150]   [loss avg: 2.5075]   [current loss: 0.0055]
# [Epoch: 151]   [loss avg: 2.4916]   [current loss: 0.0018]
# [Epoch: 152]   [loss avg: 2.4754]   [current loss: 0.0004]
# [Epoch: 153]   [loss avg: 2.4598]   [current loss: 0.0040]
# [Epoch: 154]   [loss avg: 2.4443]   [current loss: 0.0303]
# [Epoch: 155]   [loss avg: 2.4293]   [current loss: 0.0908]
# [Epoch: 156]   [loss avg: 2.4139]   [current loss: 0.0139]
# [Epoch: 157]   [loss avg: 2.3988]   [current loss: 0.0014]
# [Epoch: 158]   [loss avg: 2.3839]   [current loss: 0.0012]
# [Epoch: 159]   [loss avg: 2.3692]   [current loss: 0.0020]
# [Epoch: 160]   [loss avg: 2.3544]   [current loss: 0.0002]
# [Epoch: 161]   [loss avg: 2.3401]   [current loss: 0.0078]
# [Epoch: 162]   [loss avg: 2.3257]   [current loss: 0.0002]
# [Epoch: 163]   [loss avg: 2.3118]   [current loss: 0.0108]
# [Epoch: 164]   [loss avg: 2.3017]   [current loss: 0.0119]
# [Epoch: 165]   [loss avg: 2.2883]   [current loss: 0.0014]
# [Epoch: 166]   [loss avg: 2.2750]   [current loss: 0.0135]
# [Epoch: 167]   [loss avg: 2.2615]   [current loss: 0.0042]
# [Epoch: 168]   [loss avg: 2.2481]   [current loss: 0.0012]
# [Epoch: 169]   [loss avg: 2.2351]   [current loss: 0.0014]
# [Epoch: 170]   [loss avg: 2.2222]   [current loss: 0.0355]
# [Epoch: 171]   [loss avg: 2.2092]   [current loss: 0.0009]
# [Epoch: 172]   [loss avg: 2.1964]   [current loss: 0.0019]
# [Epoch: 173]   [loss avg: 2.1838]   [current loss: 0.0002]
# [Epoch: 174]   [loss avg: 2.1715]   [current loss: 0.0016]
# [Epoch: 175]   [loss avg: 2.1591]   [current loss: 0.0000]
# [Epoch: 176]   [loss avg: 2.1469]   [current loss: 0.0000]
# [Epoch: 177]   [loss avg: 2.1348]   [current loss: 0.0005]
# [Epoch: 178]   [loss avg: 2.1231]   [current loss: 0.0001]
# [Epoch: 179]   [loss avg: 2.1114]   [current loss: 0.0034]
# [Epoch: 180]   [loss avg: 2.0998]   [current loss: 0.0078]
# [Epoch: 181]   [loss avg: 2.0886]   [current loss: 0.0012]
# [Epoch: 182]   [loss avg: 2.0771]   [current loss: 0.0022]
# [Epoch: 183]   [loss avg: 2.0658]   [current loss: 0.0031]
# [Epoch: 184]   [loss avg: 2.0546]   [current loss: 0.0006]
# [Epoch: 185]   [loss avg: 2.0435]   [current loss: 0.0025]
# [Epoch: 186]   [loss avg: 2.0326]   [current loss: 0.0005]
# [Epoch: 187]   [loss avg: 2.0218]   [current loss: 0.0003]
# [Epoch: 188]   [loss avg: 2.0111]   [current loss: 0.0000]
# [Epoch: 189]   [loss avg: 2.0006]   [current loss: 0.0001]
# [Epoch: 190]   [loss avg: 1.9907]   [current loss: 0.1137]
# [Epoch: 191]   [loss avg: 1.9804]   [current loss: 0.0021]
# [Epoch: 192]   [loss avg: 1.9711]   [current loss: 0.0029]
# [Epoch: 193]   [loss avg: 1.9621]   [current loss: 0.0610]
# [Epoch: 194]   [loss avg: 1.9521]   [current loss: 0.0123]
# [Epoch: 195]   [loss avg: 1.9436]   [current loss: 0.0005]
# [Epoch: 196]   [loss avg: 1.9347]   [current loss: 0.0000]
# [Epoch: 197]   [loss avg: 1.9256]   [current loss: 0.0069]
# [Epoch: 198]   [loss avg: 1.9168]   [current loss: 0.0037]
# [Epoch: 199]   [loss avg: 1.9075]   [current loss: 0.0019]
# [Epoch: 200]   [loss avg: 1.8982]   [current loss: 0.0053]
# [Epoch: 201]   [loss avg: 1.8888]   [current loss: 0.0012]
# [Epoch: 202]   [loss avg: 1.8796]   [current loss: 0.0011]
# [Epoch: 203]   [loss avg: 1.8706]   [current loss: 0.0243]
# [Epoch: 204]   [loss avg: 1.8617]   [current loss: 0.0130]
# [Epoch: 205]   [loss avg: 1.8526]   [current loss: 0.0006]
# [Epoch: 206]   [loss avg: 1.8437]   [current loss: 0.0005]
# [Epoch: 207]   [loss avg: 1.8349]   [current loss: 0.0159]
# [Epoch: 208]   [loss avg: 1.8261]   [current loss: 0.0011]
# [Epoch: 209]   [loss avg: 1.8176]   [current loss: 0.0002]
# [Epoch: 210]   [loss avg: 1.8091]   [current loss: 0.0001]
# [Epoch: 211]   [loss avg: 1.8005]   [current loss: 0.0024]
# [Epoch: 212]   [loss avg: 1.7922]   [current loss: 0.0006]
# [Epoch: 213]   [loss avg: 1.7838]   [current loss: 0.0027]
# [Epoch: 214]   [loss avg: 1.7757]   [current loss: 0.0264]
# [Epoch: 215]   [loss avg: 1.7675]   [current loss: 0.0012]
# [Epoch: 216]   [loss avg: 1.7594]   [current loss: 0.0046]
# [Epoch: 217]   [loss avg: 1.7515]   [current loss: 0.0016]
# [Epoch: 218]   [loss avg: 1.7435]   [current loss: 0.0000]
# [Epoch: 219]   [loss avg: 1.7356]   [current loss: 0.0001]
# [Epoch: 220]   [loss avg: 1.7277]   [current loss: 0.0003]
# [Epoch: 221]   [loss avg: 1.7199]   [current loss: 0.0001]
# [Epoch: 222]   [loss avg: 1.7122]   [current loss: 0.0119]
# [Epoch: 223]   [loss avg: 1.7045]   [current loss: 0.0000]
# [Epoch: 224]   [loss avg: 1.6970]   [current loss: 0.0001]
# [Epoch: 225]   [loss avg: 1.6895]   [current loss: 0.0003]
# [Epoch: 226]   [loss avg: 1.6820]   [current loss: 0.0000]
# [Epoch: 227]   [loss avg: 1.6747]   [current loss: 0.0001]
# [Epoch: 228]   [loss avg: 1.6673]   [current loss: 0.0000]
# [Epoch: 229]   [loss avg: 1.6601]   [current loss: 0.0000]
# [Epoch: 230]   [loss avg: 1.6529]   [current loss: 0.0000]
# [Epoch: 231]   [loss avg: 1.6457]   [current loss: 0.0000]
# [Epoch: 232]   [loss avg: 1.6386]   [current loss: 0.0000]
# [Epoch: 233]   [loss avg: 1.6316]   [current loss: 0.0001]
# [Epoch: 234]   [loss avg: 1.6247]   [current loss: 0.0000]
# [Epoch: 235]   [loss avg: 1.6178]   [current loss: 0.0001]
# [Epoch: 236]   [loss avg: 1.6110]   [current loss: 0.0001]
# [Epoch: 237]   [loss avg: 1.6043]   [current loss: 0.0000]
# [Epoch: 238]   [loss avg: 1.5975]   [current loss: 0.0000]
# [Epoch: 239]   [loss avg: 1.5909]   [current loss: 0.0000]
# [Epoch: 240]   [loss avg: 1.5843]   [current loss: 0.0003]
# [Epoch: 241]   [loss avg: 1.5777]   [current loss: 0.0000]
# [Epoch: 242]   [loss avg: 1.5712]   [current loss: 0.0022]
# [Epoch: 243]   [loss avg: 1.5648]   [current loss: 0.0002]
# [Epoch: 244]   [loss avg: 1.5584]   [current loss: 0.0001]
# [Epoch: 245]   [loss avg: 1.5520]   [current loss: 0.0007]
# [Epoch: 246]   [loss avg: 1.5457]   [current loss: 0.0045]
# [Epoch: 247]   [loss avg: 1.5395]   [current loss: 0.0002]
# [Epoch: 248]   [loss avg: 1.5333]   [current loss: 0.0000]
# [Epoch: 249]   [loss avg: 1.5271]   [current loss: 0.0000]
# [Epoch: 250]   [loss avg: 1.5210]   [current loss: 0.0008]
# [Epoch: 251]   [loss avg: 1.5150]   [current loss: 0.0000]
# [Epoch: 252]   [loss avg: 1.5090]   [current loss: 0.0001]
# [Epoch: 253]   [loss avg: 1.5031]   [current loss: 0.0000]
# [Epoch: 254]   [loss avg: 1.4976]   [current loss: 0.0000]
# [Epoch: 255]   [loss avg: 1.4935]   [current loss: 0.0108]
# [Epoch: 256]   [loss avg: 1.4883]   [current loss: 0.0322]
# [Epoch: 257]   [loss avg: 1.4890]   [current loss: 0.0559]
# [Epoch: 258]   [loss avg: 1.4878]   [current loss: 0.1416]
# [Epoch: 259]   [loss avg: 1.4844]   [current loss: 0.1271]
# [Epoch: 260]   [loss avg: 1.4821]   [current loss: 0.1069]
# [Epoch: 261]   [loss avg: 1.4806]   [current loss: 0.1786]
# [Epoch: 262]   [loss avg: 1.4780]   [current loss: 0.0451]
# [Epoch: 263]   [loss avg: 1.4745]   [current loss: 0.0856]
# [Epoch: 264]   [loss avg: 1.4705]   [current loss: 0.0257]
# [Epoch: 265]   [loss avg: 1.4672]   [current loss: 0.0074]
# [Epoch: 266]   [loss avg: 1.4629]   [current loss: 0.0051]
# [Epoch: 267]   [loss avg: 1.4582]   [current loss: 0.0050]
# [Epoch: 268]   [loss avg: 1.4535]   [current loss: 0.0617]
# [Epoch: 269]   [loss avg: 1.4488]   [current loss: 0.0684]
# [Epoch: 270]   [loss avg: 1.4436]   [current loss: 0.0057]
# [Epoch: 271]   [loss avg: 1.4388]   [current loss: 0.0016]
# [Epoch: 272]   [loss avg: 1.4337]   [current loss: 0.0080]
# [Epoch: 273]   [loss avg: 1.4287]   [current loss: 0.0311]
# [Epoch: 274]   [loss avg: 1.4239]   [current loss: 0.0016]
# [Epoch: 275]   [loss avg: 1.4188]   [current loss: 0.0001]
# [Epoch: 276]   [loss avg: 1.4139]   [current loss: 0.0005]
# [Epoch: 277]   [loss avg: 1.4089]   [current loss: 0.0004]
# [Epoch: 278]   [loss avg: 1.4041]   [current loss: 0.0425]
# [Epoch: 279]   [loss avg: 1.3994]   [current loss: 0.0033]
# [Epoch: 280]   [loss avg: 1.3947]   [current loss: 0.0007]
# [Epoch: 281]   [loss avg: 1.3897]   [current loss: 0.0002]
# [Epoch: 282]   [loss avg: 1.3849]   [current loss: 0.0043]
# [Epoch: 283]   [loss avg: 1.3804]   [current loss: 0.0079]
# [Epoch: 284]   [loss avg: 1.3757]   [current loss: 0.0003]
# [Epoch: 285]   [loss avg: 1.3709]   [current loss: 0.0001]
# [Epoch: 286]   [loss avg: 1.3662]   [current loss: 0.0006]
# [Epoch: 287]   [loss avg: 1.3616]   [current loss: 0.0013]
# [Epoch: 288]   [loss avg: 1.3569]   [current loss: 0.0010]
# [Epoch: 289]   [loss avg: 1.3523]   [current loss: 0.0001]
# [Epoch: 290]   [loss avg: 1.3481]   [current loss: 0.0013]
# [Epoch: 291]   [loss avg: 1.3436]   [current loss: 0.0008]
# [Epoch: 292]   [loss avg: 1.3390]   [current loss: 0.0004]
# [Epoch: 293]   [loss avg: 1.3345]   [current loss: 0.0000]
# [Epoch: 294]   [loss avg: 1.3300]   [current loss: 0.0010]
# [Epoch: 295]   [loss avg: 1.3256]   [current loss: 0.0009]
# [Epoch: 296]   [loss avg: 1.3214]   [current loss: 0.0034]
# [Epoch: 297]   [loss avg: 1.3169]   [current loss: 0.0001]
# [Epoch: 298]   [loss avg: 1.3126]   [current loss: 0.0020]
# [Epoch: 299]   [loss avg: 1.3083]   [current loss: 0.0044]
# [Epoch: 300]   [loss avg: 1.3039]   [current loss: 0.0000]
# Finished Training

# %%
count = 0
# 模型测试
for inputs, _ in test_loader:
    inputs = inputs.to(device)
    outputs = net(inputs)
    outputs = np.argmax(outputs.detach().cpu().numpy(), axis=1)
    if count == 0:
        y_pred_test =  outputs
        count = 1
    else:
        y_pred_test = np.concatenate( (y_pred_test, outputs) )

# 生成分类报告
classification = classification_report(ytest, y_pred_test, digits=4)
print(classification)
# Out:
#               precision    recall  f1-score   support
#
#          0.0     0.9211    0.8537    0.8861        41
#          1.0     0.9849    0.9128    0.9475      1285
#          2.0     0.9398    0.9398    0.9398       747
#          3.0     0.9245    0.9202    0.9224       213
#          4.0     0.9674    0.9540    0.9606       435
#          5.0     0.9662    0.9559    0.9610       657
#          6.0     0.9500    0.7600    0.8444        25
#          7.0     0.9931    1.0000    0.9965       430
#          8.0     1.0000    0.4444    0.6154        18
#          9.0     0.9051    0.9703    0.9366       875
#         10.0     0.9618    0.9919    0.9766      2210
#         11.0     0.9010    0.8352    0.8669       534
#         12.0     0.9677    0.9730    0.9704       185
#         13.0     0.9819    0.9982    0.9900      1139
#         14.0     0.9126    0.9625    0.9369       347
#         15.0     0.8667    0.7738    0.8176        84
#
#     accuracy                         0.9549      9225
#    macro avg     0.9465    0.8904    0.9105      9225
# weighted avg     0.9553    0.9549    0.9543      9225

# %%
# load the original image
X = sio.loadmat('Indian_pines_corrected.mat')['indian_pines_corrected']
y = sio.loadmat('Indian_pines_gt.mat')['indian_pines_gt']

height = y.shape[0]
width = y.shape[1]

X = applyPCA(X, numComponents= pca_components)
X = padWithZeros(X, patch_size//2)

# 逐像素预测类别
outputs = np.zeros((height,width))
for i in range(height):
    for j in range(width):
        if int(y[i,j]) == 0:
            continue
        else :
            image_patch = X[i:i+patch_size, j:j+patch_size, :]
            image_patch = image_patch.reshape(1,image_patch.shape[0],image_patch.shape[1], image_patch.shape[2], 1)
            X_test_image = torch.FloatTensor(image_patch.transpose(0, 4, 3, 1, 2)).to(device)                                   
            prediction = net(X_test_image)
            prediction = np.argmax(prediction.detach().cpu().numpy(), axis=1)
            outputs[i][j] = prediction+1
    if i % 20 == 0:
        print('... ... row ', i, ' handling ... ...')

predict_image = spectral.imshow(classes = outputs.astype(int),figsize =(5,5))
# Out:
# ... ... row  0  handling ... ...
# ... ... row  20  handling ... ...
# ... ... row  40  handling ... ...
# ... ... row  60  handling ... ...
# ... ... row  80  handling ... ...
# ... ... row  100  handling ... ...
# ... ... row  120  handling ... ...
# ... ... row  140  handling ... ...
